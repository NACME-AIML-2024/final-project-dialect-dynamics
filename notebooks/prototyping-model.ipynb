# %% [markdown]
# ## Import Libraries

# %%
import torch
import pandas as pd
from datetime import timedelta
import torchaudio
import pandas as pd
import torch
from transformers import WhisperProcessor, WhisperForConditionalGeneration
from jiwer import wer

# %% [markdown]
# ## Torch Device Initialization
#
# This script checks if the Metal Performance Shaders (MPS) backend is available for PyTorch on a MacBook. If MPS is available, it sets the device to MPS. Otherwise, it defaults to the CPU. MPS is a framework by Apple that allows for efficient computation on the GPU using the Metal API.

# %%
# Check if MPS is available
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device = torch.device("cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Transcript Data Processing
#
# Now lets load transcript data, extract relevant columns, and convert time units from minutes to milliseconds for easy computation.

# %%
# Load transcript data
transcript_df = pd.read_csv('../data/coraal/transcript/text/ATL_se0_ag1_f_01_1.txt', delimiter="\t")

# Extract relevant columns
transcript_data = transcript_df[['StTime', 'EnTime', 'Content']]

# Convert times from minutes to milliseconds for easier calculations
transcript_data.loc[:, 'StTime']*=1000
transcript_data.loc[:, 'EnTime']*=1000

transcript_data
# Out:
#          StTime     EnTime                                            Content
# 0         443.6     2406.8   They talking about, don't send him to his daddy.
# 1        2406.8     2682.9                                       (pause 0.28)
# 2        2682.9     4953.8        You just need to go file for child support.
# 3        5114.2     5612.5                                        [/Oh man/.]
# 4        5148.8     5599.5                                             [Bye.]
# ...         ...        ...                                                ...
# 1228  1855602.9  1856198.4                                      [Wanna] play?
# 1229  1855826.2  1856179.8                                              [Hm.]
# 1230  1856347.3  1857625.0                        Yeah let me- let me see it.
# 1231  1858394.2  1859392.9                                   Your phone dead.
# 1232  1859417.7  1862488.4  My phone all the way- it- And the charger righ...
#
# [1233 rows x 3 columns]

# %% [markdown]
# ## Segmenting Transcript Data
#
# We segment transcript data into 30-second intervals, aggregating content within each segment. Also, we define the segment lengths in milliseconds for easier computation. Now, we intialize variables to track the start and end times of the segments. Iterating through the transcript data we can create segments, aggregating content for each 30-second interval to later save into a DataFrame.

# %%
# Define the segment length
segment_length_ms = 30000  # 30 seconds in milliseconds

# Initialize variables
start_time = transcript_data['StTime'].min()  # Start from the earliest timestamp
end_time = transcript_data['EnTime'].max()  # End at the latest timestamp
segments = []

while start_time < end_time:
    segment_end_time = start_time + segment_length_ms

    # Aggregate content for the current 30-second segment
    segment_content = ' '.join(
        transcript_data[(transcript_data['StTime'] < segment_end_time) &
                        (transcript_data['EnTime'] > start_time)]['Content']
    )
    
    # Append the segment
    segments.append({
        'Start Time': start_time,
        'End Time': segment_end_time,
        'Content': segment_content
    })

    # Move to the next segment
    start_time = segment_end_time

# Convert to DataFrame
segments_df = pd.DataFrame(segments)
segments_df
# Out:
#     Start Time   End Time                                            Content
# 0        443.6    30443.6  They talking about, don't send him to his dadd...
# 1      30443.6    60443.6  Um, year of birth? <ts> (pause 0.19) Ninety-fi...
# 2      60443.6    90443.6  Twenty-one, Twenty-one. Okay. Let's see, any o...
# 3      90443.6   120443.6  [Think he at /Grady back/.] that's a hell of a...
# 4     120443.6   150443.6  I've- I call her my sister. (pause 1.05) You k...
# ..         ...        ...                                                ...
# 58   1740443.6  1770443.6  craziest feeling in the world. Ah, man. Mm-hm....
# 59   1770443.6  1800443.6  (pause 4.15) But you got more (pause 0.39) sin...
# 60   1800443.6  1830443.6  <laugh> You can have two rooms [Yeah.] <laugh>...
# 61   1830443.6  1860443.6  (pause 6.03) When last time you played a video...
# 62   1860443.6  1890443.6  My phone all the way- it- And the charger righ...
#
# [63 rows x 3 columns]

# %% [markdown]
# ## Audio Loading and Resampling
#
# We can load an audio file using `torchaudio` to then resample it to a new frequency. The frequency accepted from our model is of 16 kHz, different from our audio data sampling rate of 44.1 kHz.

# %%
# Load the audio file and its sample rate
waveform, sample_rate = torchaudio.load("../data/coraal/audio/wav/ATL_se0_ag1_f_01_1.wav")

# Create a resampler to change the original sample rate to 16 kHz
resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)

# Apply the resampler to the waveform
waveform_resampled = resampler(waveform)

# %% [markdown]
# # Audio Segment Extraction
#
# This function
# ## Function Explanation
#
# The function `extract_audio_segment` extracts a segment from an audio file based on specified start and end times in milliseconds. The steps are as follow:
# 1. Loads the audio file using `torchaudio`.
# 2. Converts the start and end times from milliseconds to sample indices.
# 3. Extracts the audio segment corresponding to the specified time range.
# 4. Returns the extracted audio segment as a `torch.Tensor`.
#
# **Parameters**
# - `audio_file_path` (str): Path to the audio file.
# - `start_time_ms` (int): Start time in milliseconds.
# - `end_time_ms` (int): End time in milliseconds.
# - `sample_rate` (int): Sample rate of the audio file.
#
# **Returns**
# - `torch.Tensor`: Extracted audio segment.

# %%
def extract_audio_segment(audio_file_path, start_time_ms, end_time_ms, sample_rate):
    """
    Extracts a segment from an audio file based on start and end times.
    
    Parameters:
    - audio_file_path (str): Path to the audio file.
    - start_time_ms (int): Start time in milliseconds.
    - end_time_ms (int): End time in milliseconds.
    - sample_rate (int): Sample rate of the audio file.
    
    Returns:
    - torch.Tensor: Extracted audio segment.
    """
    # Load the audio file
    waveform, sr = torchaudio.load(audio_file_path)
    
    # Convert milliseconds to sample indices
    start_sample = int(start_time_ms * sr / 1000)
    end_sample = int(end_time_ms * sr / 1000)
    
    # Extract the segment
    segment = waveform[:, start_sample:end_sample]
    
    return segment

# %% [markdown]
# # Extracting Audio Segments Based on Transcript Intervals
#
# We now want to load our audio segments corresponding to transcript intervals and stores them in a list. We can iterate through each row in the `segments_df` DataFrame to extract audio segments based on start and end times.

# %%
# Define the path to your audio file
audio_file_path = '../data/coraal/audio/wav/ATL_se0_ag1_f_01_1.wav'

# Load the sample rate of the audio file
waveform, sample_rate = torchaudio.load(audio_file_path)

# Initialize a list to store extracted audio segments
audio_segments = []

# Extract audio segments based on transcript intervals
for _, row in segments_df.iterrows():
    start_time_ms = row['Start Time']
    end_time_ms = row['End Time']
    
    # Extract audio segment
    segment = extract_audio_segment(audio_file_path, start_time_ms, end_time_ms, sample_rate)
    
    # Optionally, save the segment or process it further
    audio_segments.append({
        'Start Time': start_time_ms,
        'End Time': end_time_ms,
        'Segment': segment
    })
    
# Convert to DataFrame if needed
audio_segments_df = pd.DataFrame(audio_segments)
audio_segments_df.head()
# Out:
#    Start Time  End Time                                            Segment
# 0       443.6   30443.6  [[tensor(0.0029), tensor(0.0030), tensor(0.002...
# 1     30443.6   60443.6  [[tensor(0.0001), tensor(0.0005), tensor(0.000...
# 2     60443.6   90443.6  [[tensor(0.0010), tensor(0.0006), tensor(0.000...
# 3     90443.6  120443.6  [[tensor(0.0034), tensor(0.0035), tensor(0.003...
# 4    120443.6  150443.6  [[tensor(-0.0009), tensor(-0.0012), tensor(-0....

# %% [markdown]
# We verify that the length of our transcript DataFrame is the same as our audio DataFrame.

# %%
print(len(segments_df) == len(audio_segments_df))
# Out:
# True

# %% [markdown]
# ## Initializing Whisper Processor and Model
#
# This script initializes the Whisper processor and model for the `whisper-tiny` configuration from Hugging Face's transformers library.

# %%
# Initialize processor and model for whisper-tiny
processor = WhisperProcessor.from_pretrained("openai/whisper-tiny")
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-tiny")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Move the model to the appropriate device
model = model.to(device)

# %% [markdown]
# ## Here are some details of the `whisper-tiny` model architecture

# %% [markdown]
# | Component                               | Sub-Component                                           | Details                                                                                 |
# |-----------------------------------------|---------------------------------------------------------|-----------------------------------------------------------------------------------------|
# | `WhisperForConditionalGeneration`       |                                                         |                                                                                         |
# |                                         | `model`                                                 | `WhisperModel`                                                                          |
# |                                         |                                                         |                                                                                         |
# | `WhisperModel`                          | `encoder`                                               | `WhisperEncoder`                                                                        |
# |                                         |                                                         |                                                                                         |
# | `WhisperEncoder`                        | `conv1`                                                 | `Conv1d(80, 384, kernel_size=(3,), stride=(1,), padding=(1,))`                          |
# |                                         | `conv2`                                                 | `Conv1d(384, 384, kernel_size=(3,), stride=(2,), padding=(1,))`                         |
# |                                         | `embed_positions`                                       | `Embedding(1500, 384)`                                                                  |
# |                                         | `layers`                                                | `ModuleList` containing 4 `WhisperEncoderLayer`                                         |
# |                                         |                                                         |                                                                                         |
# | `WhisperEncoderLayer`                   | `self_attn`                                             | `WhisperSdpaAttention`                                                                  |
# |                                         | `self_attn.k_proj`                                      | `Linear(in_features=384, out_features=384, bias=False)`                                 |
# |                                         | `self_attn.v_proj`                                      | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `self_attn.q_proj`                                      | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `self_attn.out_proj`                                    | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `self_attn_layer_norm`                                  | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         | `activation_fn`                                         | `GELUActivation()`                                                                      |
# |                                         | `fc1`                                                   | `Linear(in_features=384, out_features=1536, bias=True)`                                 |
# |                                         | `fc2`                                                   | `Linear(in_features=1536, out_features=384, bias=True)`                                 |
# |                                         | `final_layer_norm`                                      | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         | `layer_norm`                                            | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         |                                                         |                                                                                         |
# | `WhisperModel`                          | `decoder`                                               | `WhisperDecoder`                                                                        |
# |                                         |                                                         |                                                                                         |
# | `WhisperDecoder`                        | `embed_tokens`                                          | `Embedding(51865, 384, padding_idx=50257)`                                              |
# |                                         | `embed_positions`                                       | `WhisperPositionalEmbedding(448, 384)`                                                  |
# |                                         | `layers`                                                | `ModuleList` containing 4 `WhisperDecoderLayer`                                         |
# |                                         |                                                         |                                                                                         |
# | `WhisperDecoderLayer`                   | `self_attn`                                             | `WhisperSdpaAttention`                                                                  |
# |                                         | `self_attn.k_proj`                                      | `Linear(in_features=384, out_features=384, bias=False)`                                 |
# |                                         | `self_attn.v_proj`                                      | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `self_attn.q_proj`                                      | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `self_attn.out_proj`                                    | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `activation_fn`                                         | `GELUActivation()`                                                                      |
# |                                         | `self_attn_layer_norm`                                  | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         | `encoder_attn`                                          | `WhisperSdpaAttention`                                                                  |
# |                                         | `encoder_attn.k_proj`                                   | `Linear(in_features=384, out_features=384, bias=False)`                                 |
# |                                         | `encoder_attn.v_proj`                                   | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `encoder_attn.q_proj`                                   | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `encoder_attn.out_proj`                                 | `Linear(in_features=384, out_features=384, bias=True)`                                  |
# |                                         | `encoder_attn_layer_norm`                               | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         | `fc1`                                                   | `Linear(in_features=384, out_features=1536, bias=True)`                                 |
# |                                         | `fc2`                                                   | `Linear(in_features=1536, out_features=384, bias=True)`                                 |
# |                                         | `final_layer_norm`                                      | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         | `layer_norm`                                            | `LayerNorm((384,), eps=1e-05, elementwise_affine=True)`                                 |
# |                                         |                                                         |                                                                                         |
# | `WhisperForConditionalGeneration`       | `proj_out`                                              | `Linear(in_features=384, out_features=51865, bias=False)`                               |

# %% [markdown]
# ## Audio Preprocessing and Transcription Functions
#
# This script contains two functions:
# 1. `preprocess_audio`: Resamples an audio tensor to a target sample rate.
# 2. `transcribe_audio`: Transcribes the preprocessed audio tensor using the Whisper model and processor.
#
# ### Functions Explanation
#
# #### `preprocess_audio`
#
# This function resamples an audio tensor to a target sample rate if the original sample rate is different from the target.
#
# **Parameters:**
# - `audio_tensor` (torch.Tensor): The input audio tensor.
# - `sample_rate` (int): The original sample rate of the audio.
# - `target_sample_rate` (int, optional): The target sample rate for resampling. Default is 16000.
#
# **Returns:**
# - `torch.Tensor`: The resampled audio tensor.
#
# #### `transcribe_audio`
#
# This function transcribes the audio tensor using the Whisper model and processor.
#
# **Parameters:**
# - `audio_tensor` (torch.Tensor): The input audio tensor.
# - `model` (WhisperForConditionalGeneration): The Whisper model for transcription.
# - `processor` (WhisperProcessor): The Whisper processor for preprocessing the audio tensor.
#
# **Returns:**
# - `str`: The transcription of the audio.

# %%
def preprocess_audio(audio_tensor, sample_rate, target_sample_rate=16000):
    if sample_rate != target_sample_rate:
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=target_sample_rate)
        audio_tensor = resampler(audio_tensor)
    return audio_tensor

def transcribe_audio(audio_tensor, model, processor):
    audio_tensor = audio_tensor.to(device)
    inputs = processor(audio_tensor.squeeze().cpu().numpy(), return_tensors="pt", sampling_rate=16000)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        predicted_ids = model.generate(**inputs)
    transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)
    return transcription[0]

# %% [markdown]
# # Transcribing Audio Segments and Comparing Results
#
# We want to test the pre-trained `whisper-tiny` model with our data (albeit is it not yet cleaned). After pre-processing our audio and transcript we go into transcribing the audio segment. We append the actual and predicted transcriptions to the respective lists to later print out the start time of the segment, actual transcript, and model transcription.
#
# **Variables**
#
# - `true_transcriptions` (list): List to store the actual transcriptions.
# - `predicted_transcriptions` (list): List to store the model-generated transcriptions.

# %%
# Initialize lists for metrics
true_transcriptions = []
predicted_transcriptions = []

# Process each segment and compare transcriptions
for idx in range(len(audio_segments_df)):
    audio_tensor = audio_segments_df['Segment'][idx]
    actual_transcript = segments_df['Content'][idx]
    
    # Ensure audio is in the correct format
    audio_tensor = preprocess_audio(audio_tensor, sample_rate)
    
    # Transcribe audio
    model_transcription = transcribe_audio(audio_tensor, model, processor)
    
    # Store transcriptions for metric calculation
    true_transcriptions.append(actual_transcript)
    predicted_transcriptions.append(model_transcription)
    
    # Print segment info
    print(f"Segment Start: {audio_segments_df['Start Time'][idx]}")
    print(f"Actual Transcript: {actual_transcript}")
    print(f"Model Transcription: {model_transcription}")
    print("\n")
# Out:
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Segment Start: 443.6
# Actual Transcript: They talking about, don't send him to his daddy. (pause 0.28) You just need to go file for child support. [/Oh man/.] [Bye.] Why? (pause 0.80) Why? Okay, what's your name? /RD-NAME-2/ (pause 0.52) /RD-NAME-1/ what? (pause 0.48) /RD-NAME-3/ Okay. (pause 0.61) And, uh, (pause 0.39) are you a male or female? I'm a girl, I think. [<laugh>] [I'm just playing.] Okay. (pause 0.19) And your ethnicity? Hum, I'm supposed to say, black or non-hispanic. Okay. (pause 0.74) Um, year of birth?
# Model Transcription:  I said, I don't see him to his daddy. You just need to go far for child support. Why? Why? Why? Okay, what's your name? Boy. Okay. And, uh, are your middle female? Oh, I think. How does that sound? Okay, and, uh, ethnicity. Um, I'll pass by black and not his family. Okay. Um,
#
#
# Segment Start: 30443.6
# Actual Transcript: Um, year of birth? <ts> (pause 0.19) Ninety-five. Okay. Nineteen-ninety five, (pause 0.33) that was a good year. (pause 0.56) Um, hometown? <ts> (pause 0.18) Stone Mountain. Okay, we in the Mount with it. (pause 0.66) Neighborhood. <ts> (pause 0.09) [/RD-ADDRESS-4/] [/RD-ADDRESS-4/.] Okay. (pause 0.10) /RD-ADDRESS-6/, we- we in here. Let's see what else, um, (pause 0.52) How many years have you been in the Atlanta area? Psh, twenty-one. Okay. Twenty what? Twenty-one, Twenty-one.
# Model Transcription:  You're a birth 95 Okay, 1995 that was a good year home town Stone County Okay, we're in the mountain with neighbors Okay, let's see what else How many years have you been in Atlanta, Ari? 21. Okay 21 21 21
#
#
# Segment Start: 60443.6
# Actual Transcript: Twenty-one, Twenty-one. Okay. Let's see, any other places lived? Nah, I don't know nothing [else.] [You] ain't gonna claim nothing else? Nah, [this all I know.] [Okay. <laugh>] Alright, [let's see], Shut up. um, (pause 2.01) your parent's birthplace? <ts> (pause 0.15) Ooh, my daddy was born (pause 1.00) in- where my daddy was born at? (pause 0.17) My mama was born in Florida. My daddy was born in Decatur. Okay. Atlanta, (pause 0.31) one of them. (pause 0.25) [Think he at /Grady back/.] [Wow that-]
# Model Transcription:  Okay, and the other places live. No, no, no, no. You ain't gonna claim that you're no. No, this is all I know. All right, let's, um, your parents first.
#
#
# Segment Start: 90443.6
# Actual Transcript: [Think he at /Grady back/.] that's a hell of a connection. (pause 0.47) Let's see- (pause 1.62) And, uh, (pause 0.85) if you didn't know already, my name is /RD-NAME-3/ and I will be, (pause 0.75) the interviewer of the day. (pause 0.74) And, um, (pause 0.14) today is (pause 0.32) I believe the twenty-sixth of January? Yep. Okay. (pause 0.96) And, um, (pause 1.24) the person I'm interviewing is (pause 0.84) friend of family, uh (pause 1.30) I've- I call her my sister.
# Model Transcription:  So hello connection. Let's see. And if you didn't know already, my name is Dan, I will be the interviewer today. And today is, I believe, the 26th of January. Yep. Okay. And the personal man in the building is, friend family. I'll call him a sister.
#
#
# Segment Start: 120443.6
# Actual Transcript: I've- I call her my sister. (pause 1.05) You know. (pause 0.47) She the folk around here, so. (pause 0.65) As we're continuing, um, (pause 1.02) let's see, the recording equipment we're using (pause 0.67) is the Zoom Handy H five recorder. (pause 0.26) Okay, so now I'm finna get into some more (pause 0.45) general (pause 0.27) topics, or whatever. (pause 0.78) Um, do you have any siblings? I have four brothers (pause 0.15) and two sisters. God damn. (pause 0.49) <laugh> Yes. <laugh> (pause 0.80) Okay, um
# Model Transcription:  I have four brothers and two sisters.
#
#
# Segment Start: 150443.6
# Actual Transcript: Okay, um (pause 1.54) are you close to any of your aunts, your uncles, grandparents, cousins? Psh, (pause 0.42) all of 'em. (pause 0.20) But everybody just pretty much got they own thing going on, so. You know when you grow older, Mm-hm. and you just, you know, start (pause 0.62) pretty much yeah. Doing your own thing, yeah. (pause 0.81) Can't really link up how you used to, but that don't mean we not close. Ah, nah. Everybody got a life to live. (pause 1.21) But that's cool man. But when, uh, um, next time you think y'all having a family reunion?
# Model Transcription:  Are you close to any of your aunts your uncles grandparents cousins? All of them but everybody just pretty much get their own thing going on so you know when you go older and you just start pretty much yeah doing your own thing and Can't really make up how you use to but that'll maybe not close
#
#
# Segment Start: 180443.6
# Actual Transcript: But that's cool man. But when, uh, um, next time you think y'all having a family reunion? We [just] had one in July. [Oh.] Okay. Twenty-sixteen, so. [/Still been a while/.] [It might be twenty-] twenty-eighteen, before we have another one. Okay. <cough> (pause 0.12) [Excuse me.] [How was it?] <ts> (pause 0.20) It wasn't as big as I thought it would be. [Mm.] [It was] like everybody- It wasn't good timing. People wasn't- [Ah.] [A lot of] people didn't really show up. [Yeah.] [But] we still enjoyed the people that we did have. Oh no [that's what's up.] [And it was more so] the older people. And that's who you wanna see before they check out, you know. <laugh> (pause 1.05)
# Model Transcription:  We just had what in July 2016 so it might be 2018 for we have another one It wasn't as big as I thought it would be it was like everybody it wasn't good time in people when a lot of people didn't really show up But we still enjoyed the people that we did and it was more so to older people and that's what you want to see for they check out you know
#
#
# Segment Start: 210443.6
# Actual Transcript: (pause 1.05) No that's for real. /That man-/ (pause 0.21) Fucking broke some shit over here. (pause 0.62) Let's see (pause 1.76) Um, let's see, um, blah, blah, blah, blah, blah. (pause 1.02) Why thank you. (pause 0.80) Thank you. (pause 2.96) So, um- <cough> Ooh, excuse me Four [siblings], um, [<cough>] I know you say you had a lot of- what? Four brothers, two sister- (pause 1.23) Um, (pause 0.19) who's younger, (pause 0.30) or older, or where you reside in the mix?
# Model Transcription:  Let's go. Let's see. Let's see.
#
#
# Segment Start: 240443.6
# Actual Transcript: or older, or where you reside in the mix? I'm (pause 0.18) the oldest girl. (pause 0.25) And the second oldest (pause 0.12) out of them. I only got one big brother. Everybody else younger than me. (pause 0.37) And me and him are only seven months. (pause 0.22) Then you got /RD-NAME-3/, eighteen. Uh-huh. And then I got twins. [They're eleven.] Then I got /RD-NAME-2/, he's four. [Mm-hm.] And /RD-NAME-2/ is only (pause 0.39) October, November, December, January, February, /March/- She's only four months. Okay. Out of all of those you got a favorite?
# Model Transcription:  Where you reside in the midst? The oldest girl in the second oldest, I don't know, I only got one big brother. Everybody else younger than me. Me and him only seven months. Then you got 18 and I got twins. There are you, Abby. Then I got a piece for her. It's only, so I'm gonna just send the chain from her. She's only four months. Okay, and all of those you got a favorite.
#
#
# Segment Start: 270443.6
# Actual Transcript: Can't really put a name on it, [but] you know, /RD-NAME-3. [<laugh>] (pause 1.95) Hey, okay. Cause we the closest. Nah, definitely. But- (pause 0.24) And my big brother, he grew up (pause 0.65) with his mom so, (pause 0.39) ev- and then the other four (pause 0.40) they just so much younger so. (pause 0.42) [And then] personally, me and /RD-NAME-3/ just always had a bond. [<cough>] Okay. Did you feel like (pause 0.19) /RD-NAME-3/ got away with more things than you did? Or you got away with more things than she did? Um,
# Model Transcription:  Can't really put a name on it, but you know Because we do closest But am I big brother he grew up with his mom so airf and then the other four they did so much younger so then personal me this always had a bone Okay, did you feel like? Got a wedding more things than you did or you got a wedding more things than she did
#
#
# Segment Start: 300443.6
# Actual Transcript: Um, <cough> I feel like she did (pause 0.27) [because] [<cough>] I don't know. /RD-NAME-3/ (pause 0.09) /RD-NAME-3/ could get away with murder. (pause 0.17) And Zaria- (pause 0.31) Zaria conscious is not like mine. I- (pause 0.15) I care. [Mm.] [/RD-NAME-3/] got a I don't give a fuck mindset. Yeah. And sometimes I'm like that too, (pause 0.13) [but] [Mm-hm.] more so her, cause she don't even care. Oh, cool, cool, cool. (pause 0.49) So we- we speaking on, (pause 1.13) you know, fam, and that's good that you got a good relationship
# Model Transcription:  I feel like she did because I don't know Get away with murder and Conchishes not like my I care I don't give a fuck my I said yeah, it's sometimes I'm like that too, but more so her cause she'll be care
#
#
# Segment Start: 330443.6
# Actual Transcript: you know, fam, and that's good that you got a good relationship (pause 0.80) with them. (pause 0.24) What about, um, (pause 0.38) your relationship as far as your friends and stuff like that? Um, I'm not really a friend person. (pause 0.37) I have so much family, like (pause 0.54) we so close. I got one cousin, I got one friend- Mm-hm. And then I got my sister. That's beautiful. (pause 0.31) You can count them all on a hand. That's- (pause 0.18) I mean might have (pause 0.35) some good quality over quantity. (pause 0.62) [That's how I would] look at it. [Hell yeah.] Um, And [they] the only ones who stayed down [like] hey. was- (pause 2.00) [<laugh>] [Everybody], let's go. [So-]
# Model Transcription:  I feel like I have a relationship with them. What about your relationship as far as your friends and stuff like that? I'm not really a friend, person. I have so much family like we so close. I got one cousin, I got one friend and then I got my sister. That's a beautiful, kind of model on the hand. That's to me. I have some good quality over quantity. I'm so good. And then I was just saying, hey, everybody.
#
#
# Segment Start: 360443.6
# Actual Transcript: [Everybody], let's go. [So-] So your one friend in- in particular, (pause 0.28) um, what do you do together (pause 0.18) with that friend? <ts> (pause 0.27) Smoke, (pause 0.12) [workout], eat. [Okay.] Yeah. Talk about boys. [Yeah.] [/?/] [How- how'd-] [Just chill.] how'd you meet him? Sixth grade. At /RD-SCHOOL-6/. Uh, okay, okay. That's (pause 0.73) over a decade right about there. (pause 0.82) Damn near. Yep. Let's see, um, (pause 2.38)
# Model Transcription:  So you're one friend in particular, what do you do together? Smoked workout eat. Yeah. Talk about boys. Yeah. How do you eat them? It's great. Wow. Okay, this. Oh, our deck here right now. Yeah. Yeah. Let's see.
#
#
# Segment Start: 390443.6
# Actual Transcript: (pause 2.38) since you said something about, um, (pause 0.19) about school. (pause 0.29) How was school for you (pause 0.17) coming up? <ts> (pause 0.17) Um, (pause 0.47) school was (pause 0.40) what- (pause 0.37) what you made it at my school. When I went to /RD-SCHOOL-3/ el- Well /RD-SCHOOL-3/ middle and high. And I went to /RD-SCHOOL-2/ elementary and it was like (pause 0.44) in the beginning, (pause 0.65) it was good. It was a excellent school you know. We was all (pause 0.10) cool. And then you got folks moving in from crazy areas. Then you got everybody else. Around my area growing up, venturing out and stuff.
# Model Transcription:  She said something about a school how was school for you coming up? School was what what you made at that my school I went to the other was a little high and I went to elementary and I was like in the beginning it was good it was an excellent school you know we was all cool and then you got folks moving in from crazy areas and you got everybody else around that area you're growing up
#
#
# Segment Start: 420443.6
# Actual Transcript: cool. And then you got folks moving in from crazy areas. Then you got everybody else. Around my area growing up, venturing out and stuff. [Mm-hm.] [So] it's like, one day you might have- (pause 0.53) We might make- (pause 0.27) What is it called? The, um, (pause 0.32) we might meet all our criterias, or something then the next day, (pause 0.35) they want a food fight, (pause 0.19) or something like that. Mm-hm. (pause 0.43) [<laugh>] [Or], (pause 0.63) [or] the next day you know, you got these gang members quote unquote. Coming in and out of the school. We like, who are y'all? Where'd y'all come from? So /wrong way/ um, (pause 0.42) I guess, what grade was that happening? That was like seventh grade.
# Model Transcription:  the venture-nodded stuff. So it's like one day you might have, we might make, what is it called? We might meet all our criteria to something. The next day they want to fool fight or something like that. Or what the next day you know, you got these gang members quote unquote coming in and out of school. We like, who are you, where you are, where you are come from? So I guess what grade was that happening? That was like, seven grades.
#
#
# Segment Start: 450443.6
# Actual Transcript: Okay. (pause 0.20) Damn. (pause 0.30) Early. (pause 0.20) <laugh> Seventh grade you start having all the /ratchetness/. Okay, okay, okay, let's see, um. (pause 1.71) How many students used to go? (pause 1.35) How big were y'all classes and shit? Well, (pause 0.32) I always- (pause 0.57) Well when I got in high school, I took, um, (pause 0.18) AP classes. but throughout middle school, Mkay. it was like thirty and (pause 0.09) forty kids in a classroom. [/unintelligible/] [It used to be] so hot.
# Model Transcription:  Okay, damn, early. Seven grades, not having an art of wretchedness. How many students used to go? How many students used to go? How many were your classes in school? Well, I always, well, when I got in high school, I took on AP classes, but throughout middle school, that was like 30 and 40 kids in the classroom.
#
#
# Segment Start: 480443.6
# Actual Transcript: [It used to be] so hot. [<laugh>] [But] in high school, I only had maybe like, ten, eleven people in my class. Oh, okay. Sometime- twenty at the most. Okay. That's a good day. (pause 0.19) Twenty at the most. (pause 1.16) What, um, (pause 0.45) what kind of subjects did you take? Of course the basics. Math, reading and science, social studies. (pause 0.41) Then I got, [um], [Gotta] have that. <ts> (pause 0.20) biology and AP geometry, and (pause 0.46) AP (pause 0.74) whoever else.
# Model Transcription:  But in high school, I only had maybe like 10 living people in my class. Sometimes 20 at the most. Of course the basis now, breathing in science, social studies, then I got biology, and AP, geometry, and AP, whoever has a
#
#
# Segment Start: 510443.6
# Actual Transcript: whoever else. (pause 0.16) <ts> Yeah. Um, (pause 0.78) all those different maths. And then they had of course, biology, chemistry, (pause 0.79) physical science and all that, economics. Ooh. Y'all had economics early? Mm-hm. (pause 0.59) [Not] middle school, that was like, high [school.] [I-] (pause 1.36) [Oh], okay. I- I see. I ain't did economics til college and shit. Oh no, I had economics like (pause 0.27) tenth grade. Do you remember anything from the classes? Course you can remember math, cause that's your money
# Model Transcription:  I don't know if there's any other thing about this.
#
#
# Segment Start: 540443.6
# Actual Transcript: Course you can remember math, cause that's your money (pause 0.16) <cough> [Yep.] [<cough>] <cough> (pause 0.75) English and (pause 0.42) stuff like that. Literature and stuff like that (pause 0.70) it- (pause 0.14) <cough> (pause 0.42) broadens your va- vocabulary and (pause 0.42) it (pause 0.62) opens your mind to, I guess, (pause 0.36) believe and (pause 0.29) think. And then of course you got history and stuff. (pause 0.57) You got (pause 0.93) you know, some history- (pause 0.33) well all history really is our history, [but then] you hear [Uh.] different aspects and different point of views as you grow older.
# Model Transcription:  English stuff like that little chair stuff like that it brought in your vocabulary it opened your mind to I guess believe and then of course you got history and stuff you got you know some history well all history really is our history but then you hear different aspects and different point of view
#
#
# Segment Start: 570443.6
# Actual Transcript: different aspects and different point of views as you grow older. (pause 0.27) And then you eventually get your own mindset. And [chemistry] and science and stuff like that [Oh.] I ain't really go for all that cause I got a real weak stomach. [<laugh>] [But] everything else was- everything else was pretty cool. Like (pause 0.24) real cool. You gotta be a certain type of individual to be a doctor, man. Yeah. [And I had- My major] was gonna be nursing. [Opening people up and stuff like that.] [Mm-hm.] [Like] I switched my major up soon as I took them classes. I'm like, oh, my stomach is (pause 0.09) too weak. I was in those classes they was trying to get us to [dissect.]
# Model Transcription:  I was like, I'm really good at it.
#
#
# Segment Start: 600443.6
# Actual Transcript: too weak. I was in those classes they was trying to get us to [dissect.] [<cough> oh boy] [I'm like dissect?] Only thing I know how to do is gut fish. [Yeah. <laugh>] [Like, they got a pig out here.] Oh yeah they did. Frogs, I [hate them.] [Mm-hm.] Mm-hm. We got all kind of stuff. Oh my goodness I [never-] [So] I just switched to social work. Nah. And that's still something in itself as well. [Cause I do-] [/It's all/] shit. Tell you. [<laugh>] That's what I do. That's what I get. [<laugh>] /Jug/ on /jug/ action right there. (pause 0.19) Let's see. (pause 0.91) Um, what was your favorite subject though?
# Model Transcription:  I'm like that's it. I don't think I know how to do it's good fish. Yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah, yeah
#
#
# Segment Start: 630443.6
# Actual Transcript: Um, what was your favorite subject though? Math. I knew it was gonna be math. [The way you talk about m-] [Not just because of money, but] just because [Yeah.] that's always been the subject that I could like, (pause 0.45) I could understand fast. Like, my grandma and my cousins (pause 0.17) [they] used to pay me [Oh.] to do they math work. (pause 0.29) Like Oh shi- I'm finna have you help me out with some math then. Oh, yeah. I'm a genius in math. My mama is too [like-] [Oh] yeah your mom- I can tell your mom was fire with the math. My mama was real fire with math. (pause 1.55) But I don't even-
# Model Transcription:  I know it's gonna be mad at me. Not just because of money, but just because. That's always been the subject that I could like I could understand fast like my grandma and my cousin's the pay me the do they math work like. Oh yeah, I'm a jeans and my mom is too. I can tell you my father. My mom will real file with math.
#
#
# Segment Start: 660443.6
# Actual Transcript: But I don't even- (pause 0.64) [My daddy real smart with it too], but he- [/unintelligible/] he don't know like the (pause 0.26) once they added all the letters and all that. that's [when you lost him.] [Oh, yeah], yeah. Okay, Okay. that's two different type of math [/unintelligible/.] [Yeah.] But he can add up some numbers in his head in a heartbeat. (pause 7.04) What kind of math you thinking? I don't know. I'm just looking at a math book. <cough> (pause 0.16) <cough> Oh, that ain't even yours.
# Model Transcription:  I'm not a daddy real smart with it too, but he don't know like the what's the added out of letters and I did that's okay. Okay, that's two different type of math. Yeah, but he can add up some numbers and he's in a heartbeat. What kind of bad do you think?
#
#
# Segment Start: 690443.6
# Actual Transcript: <cough> Oh, that ain't even yours. Hell nah. (pause 0.09) [<laugh>] [<cough>] I bet [<cough>] [there's, um], This is really my auntie's. (pause 0.40) This joint so old though. I think this joint came out like the eighties. (pause 5.22) The two-thousands finna be considered old. <ts> (pause 0.14) Right. [/unintelligible/.] [Bro.] All our generation is twenty-one. (pause 2.54) Ninety-six babies,
# Model Transcription:  I don't know any of the lyrics.
#
#
# Segment Start: 720443.6
# Actual Transcript: Ninety-six babies, (pause 0.38) is finna be twenty-one. (pause 2.30) /RD-NAME-3/ is about to be twenty-one in a little while. (pause 2.06) [I-] [I don't see] how the fuck they could trip on little niggas not knowing who Tupac was. Like, (pause 0.51) niggas wasn't growing up when Tupac was like out like that. That's what I'm saying. Like. Like, [They don't compare now-] [but I bet you if you ask on somebody] they know, like you could ask these folks, Kendrick Lamar, just speaking on J Cole- Yeah. Of course Young Thug. And the- those [kind of rappers but rappers] in that, like [You know that shit?]
# Model Transcription:  It's been a B-21. Is that a B-21? In a little while.
#
#
# Segment Start: 750443.6
# Actual Transcript: Of course Young Thug. And the- those [kind of rappers but rappers] in that, like [You know that shit?] you can ak- you can't ask them about that. Like, that's before they time. Like we going out of our way to follow that shit. Just [cause we fuck] with like, [Yeah.] the nineties and shit like that. They don't /have/ to fuck the nineties /at all though/. (pause 2.49) I barely made that shit. Like, I'm like kind of half way between both of 'em right [now.] [<laugh>] Really [wanna] bridge the gap on that man. [Mm.] Do what I can. (pause 0.63) I just like both of 'em man. (pause 0.08) Really all of them joints the same for real for real when you really think about it.
# Model Transcription:  You can't ask him about that. That's before the time.
#
#
# Segment Start: 780443.6
# Actual Transcript: Really all of them joints the same for real for real when you really think about it. Yeah? Especially if you know about numbers and stuff like that. Yeah? So what- (pause 0.28) uh, you know about decimals? (pause 0.29) [/???/] [Mm-hm.] Okay. (pause 0.67) Ain't gonna lie, I was like, oh man I forgot how to say this word. (pause 0.51) /??/ Yeah. Some of that stuff, you be like what? /RD-NAME-3/ be showing me some work. They got- they got- (pause 0.17) these days, they got new stuff. Mm-hm. Like, (pause 0.27) I'm like, I ain't never seen that when I was in school /RD-NAME-3/.
# Model Transcription:  I was like, I never seen that when I was in school.
#
#
# Segment Start: 810443.6
# Actual Transcript: Oh she did have that, like a- new ways of looking [at the numbers though.] [Yeah.] She had- No, she just had some problems she showed me on her online class. It was [like], [<laugh>] I don't even remember what it was, but I'm like, okay. (pause 0.27) I'm getting the beginning, solving it first. (pause 0.38) And then they start talking about regions and something. And I'm like, what the fuck is [a region?] [<laugh>] Okay. (pause 0.48) Now this one is- (pause 0.22) For example, this joint is saying it out, plain as day, and I'm still having it (pause 0.73) trouble getting at how that happened. (pause 0.24) Although they worked it out and everything.
# Model Transcription:  Oh, she didn't have it. Like, I'm no way. Yeah, she had no, she had some problems. She showed me all her online class. It was like, I don't even remember what it was, but I'm like, okay, I'm getting the book in it, so I'm in the first and then it started talking about regions and some, I'm like, what the fuck is the region? Okay, now this one for example, this one is saying about playing in the game. I'm still at the middle. So we're getting it. How did it happen? I love it. It worked without in everything.
#
#
# Segment Start: 840443.6
# Actual Transcript: Oh, they just dropped the decimal and subtract it from the- <ts> just like you do regular subtraction. Okay, so (pause 0.53) what's that? Four hundred thirty-six dollars and (pause 0.13) seventy-two cents? (pause 1.32) Subtract- well, minus (pause 1.16) forty-nine dollars and (pause 0.33) forty-six [cents?] [Mm-hm.] And what'd that give me? Ha, three hundred eighty-seven dollars and [twenty-six cent. (laughing)] [<laugh>] [<laugh>]
# Model Transcription:  Oh, they just dropped this one. It's a trachea from this. Just like you do regular subtraction. Okay, so was that $436 or 72 cents? Subtract minus $49.46. I wasn't gonna give you. Yeah, 387.26.
#
#
# Segment Start: 870443.6
# Actual Transcript: [<laugh>] [<laugh>] [Hey, but would you be able] to do that without like that- that paper right in front of you. [Like if somebody] told you that. You'd just know that exact number like that? [Yeah.] (pause 2.35) I've been calculating money like that cause at the little job I work, [My bro does this shit too], bruh, I'm not even doing that anymore. [at, um-] Yeah this little- What's that? Oh, (pause 0.91) at the, um, they don't have (pause 0.30) registers and stuff. so you gotta [do it all in your head. So I] just be like [Oh, shit /??/.] <ts> (pause 0.51) Remember orders, all that [different stuff. Yo.] [Yeah.] And their food so doggone good. Like,
# Model Transcription:  I'm calculating money like that because at the little job I work. Yeah, this is the, what's that? Oh, they don't have registers and stuff. So you gotta go out the head. So I just be like, remember, or is on it? Yeah, and that food so does.
#
#
# Segment Start: 900443.6
# Actual Transcript: And their food so doggone good. Like, (pause 0.13) [ooh.] [/unintelligible/.] /???/ (pause 1.40) Let's see, um, (pause 2.12) what kind of music do you like right about now? <ts> (pause 2.28) Mm. (pause 2.16) I guess you could say (pause 0.13) Hip Hop and R and B, (pause 0.16) cause I love to sing. Yeah. But (pause 1.51) sometimes I just can't listen to all that. I just be liking the beat to a hip hop [song.] [The beats.] [The damn beats.] [I be listening to the] beats.
# Model Transcription:  I guess she could say hip hop and R&B because I love to sing. But sometimes I just can't list out. I just see like in the beat.
#
#
# Segment Start: 930443.6
# Actual Transcript: [The damn beats.] [I be listening to the] beats. <ts> (pause 0.22) Oh, you got R and B and a good beat going together? That's pretty cool too. [Yeah.] August Alsina pretty good doing that. I don't really listen to him like that. Ah man. I don't neither, (pause 0.19) but I just know [all of- when I hear his music, /that dude/-] [Yeah I heard a few of his songs. Yeah.] [Right.] [/When you/] straight. Jeremiah, he turnt up too. Yeah? (pause 1.04) [Sometimes] he just need to lower his voice though. [I'll-] (pause 2.02) <laugh>
# Model Transcription:  Yeah. Yeah. Sometimes he just need to lower his voice down.
#
#
# Segment Start: 960443.6
# Actual Transcript: <laugh> Two Chainz about to come out with a album called (pause 0.25) girls love trap [music.] [I] thought you was about to say Two Chainz about to start singing and [I was about to say hell no.] Oh no, he might on this [hit, bruh], but I don't know. (pause 0.30) We gonna see. Mm-hm. He been coming out with some bangers lately though. I love Two Chainz. <ts> (pause 0.14) Yeah. [It's so-/] [And Future.] Dang. <whispered> (pause 0.16) Future. (pause 1.15) He really been chilling lately. He might start turning back up [again.] [Exactly.] But he been chilling in a good way though. Like
# Model Transcription:  I thought she was babysitting.
#
#
# Segment Start: 990443.6
# Actual Transcript: But he been chilling in a good way though. Like [Yeah.] [He] been all over the place. You can understand him [<clears throat>] [/You know like/ Thug starting to get on that too. Psh, [is] he? [I-] (pause 0.27) [I] thought he was not gonna stop dropping mix tapes /when I was with him/. He [chilling right now.] [Exactly.] [I for-] [Ah never mind.] His last album. He was in a dress. Went all the way out. Oh, okay. Was that a dress? (pause 0.77) That was definitely a dress [right?] [Yeah] talking about that cheetah? [No, not the cheetah one, but um.] [<laugh>]
# Model Transcription:  I think the good way though, even I'll over the place, you can understand him.
#
#
# Segment Start: 1020443.6
# Actual Transcript: [No, not the cheetah one, but um.] [<laugh>] The album cover one with like the wedding type dress. <ts> (pause 0.08) Yes, talking about- Yeah I know what you talking about. Hey man, that's good publicity right there. (pause 0.55) Really turnt. What this five thirty, man. Would you trip- Ay, would you trip if, um, (pause 1.82) JJ wanted to, um, where one of them dresses like that?
# Model Transcription:  No, not the T to one. The album cover line. Like the waiting time. Yeah, it's time. Yeah, no, it's time. Hey, man. That's a bit publicity right here. Really time. What? What?
#
#
# Segment Start: 1050443.6
# Actual Transcript: JJ wanted to, um, where one of them dresses like that? Yeah I'd trip. [<laugh>] [I did not have no little girl.] <cough> (pause 1.55) I mean I just- (pause 0.45) parenting right there. (pause 0.72) /unintelligible/. It's not- I'm not gonna say it ain't good parenting, (pause 0.66) cause you can't say, (pause 2.05) hm- I will personally say, it was like a unwritten rule. you gotta at least let 'em just grow up first, (pause 0.69)
# Model Transcription:  And just like that? Yeah, true. I did not have no girl. I made it as just parents and I did. It's not, I'm not saying good parents, because you can't say. I will personally say it was like an arm roll. You got least let them just grow up first.
#
#
# Segment Start: 1080443.6
# Actual Transcript: (pause 0.69) before they make that type of decision [on like /??/.] [Right, like] And then I be seeing these videos. These mama's be letting they little boys dance and stuff. Like this lady had her son dancing in a dress. (pause 0.65) And the little boy just doing it. Like, (pause 0.73) I will beat the shit [out of JJ like-] [<laugh>] I mean I get how it was funny and shit [like that-] [No, that is] not funny. I don't find [that funny at all.] [I mean] if it's not funny, then it just like, okay they doing they thing. They turnt, but- <cough> little crazy. <cough>
# Model Transcription:  before you make that type of decision. Right, lady. And then I've been seeing these videos these mom was be letting their little boys dance and stuff like this lady had her son dancing in the dress and a little boy just doing it like I will beat the shit out of JJ. I mean I get how it's funny and she'll know that it's not funny. I don't find it's funny at all.
#
#
# Segment Start: 1110443.6
# Actual Transcript: little crazy. <cough> (pause 0.14) Alright bro. (pause 4.14) It going to be an interesting time /to wonder/. Very. Cause I don't think my mama would let that shit going down either. (pause 0.68) I would just- (pause 0.43) I just wanted my /thing personally/. [You can't say-] [I wo- I would] hope she would know to do that shit. God damn. <laugh> I don't know. You can't judge them and all that stuff, but
# Model Transcription:  I
#
#
# Segment Start: 1140443.6
# Actual Transcript: I don't know. You can't judge them and all that stuff, but I'm not [judging nobody.] [I don't-] (pause 0.24) Yeah. I'm preventing it the best way I can. Like why? I just wanna know why you feel like (pause 0.67) dick in a booty is okay. Like (pause 1.00) why? [What?] [I would wanna know] too. [Why JJ?] [A-] (pause 0.19) [a decent explanation.] [No- not] even why JJ, cause I know that's not gonna happen to him. [But-] [I get] that. I get that. Like why would you? (pause 0.82) <ts> (pause 0.95) What's the matter? I don't know. I'm curious too. (pause 5.34)
# Model Transcription:  I'm not a student, but I'm not a student. I'm not a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student. I'm a student.
#
#
# Segment Start: 1170443.6
# Actual Transcript: (pause 5.34) <laugh> (pause 2.61) What's another thing we could talk about? I don't even know [like], [<laugh>] [that just threw me.] <laugh> [Shit.] [Huh.] Nah, that was real. Mm-mm. Yep, you never try to play no [instrument?] [<cough>] Never try to play who? A instrument? (pause 0.46) You wasn't in band, or no shit? Man, I tried to play the flute. (pause 0.62) [That] didn't work out. [Hm.]
# Model Transcription:  I don't even know that is through me Never try to play the flute
#
#
# Segment Start: 1200443.6
# Actual Transcript: Okay. The recorder, boy I was the shit on the recorder boy. In fifth grade- Yeah. <laugh> (pause 0.45) So I tried to advance [to the flute.] [I ain't gonna lie.] I knew a couple of little notes on the recorder too. I was turnt for a second and then it just started getting advanced. It just started (pause 0.53) turning into some other flute type stuff, like nah, /??/ with a recorder. (pause 1.08) Oh, snap. What if somebody brought again, a old school (pause 0.72) elementary school recorder and putting 'em on a trap beat.
# Model Transcription:  The recorded boy out the shit on the recorded boy in fifth grade
#
#
# Segment Start: 1230443.6
# Actual Transcript: elementary school recorder and putting 'em on a trap beat. Boy that'd be fire, if they all playing it together. Ooh. You'd get a couple of 'em. How you got a [roll with no weed?] [<humming>] Bro, I knew I just had a lighter, [like] Ah, man. I /??/ again. <ts> (pause 0.27) . (pause 3.81) Oh my gosh. Let's see, (pause 0.99) Donald Trump is the president. Man, I don't even wanna speak on that. Donald Trump [is your president. Obama is my president. Okay?]
# Model Transcription:  We're there to be five they are playing it together. Oh
#
#
# Segment Start: 1260443.6
# Actual Transcript: Man, I don't even wanna speak on that. Donald Trump [is your president. Obama is my president. Okay?] [<laugh> /unintelligible/] [Oh, man.] [Obama is my] president. Man. (pause 0.79) I'm really, you know, (pause 0.89) the type of person I am, (pause 0.25) you know. I give people the benefit of the doubt so hard. [Yeah?] [Like], everybody. Even trying, I'm like, maybe he ain't gonna do (pause 0.43) nothing bad at all. (pause 1.02) Maybe. Just maybe bro. Just damn maybe. Just damn maybe. (pause 4.47)
# Model Transcription:  Your president Obama is my president, okay Obama is my president I'm really you know the type of person I am you know I get people to benefit at the doubt so hard Yeah Just maybe bridges damn maybe
#
#
# Segment Start: 1290443.6
# Actual Transcript: (pause 4.47) Dang bruh. (pause 1.08) Did they Pac Obama? Not that I know of. Bruh, Obama wasn't- the president for eight years and he couldn't (pause 0.15) save black people. (pause 2.03) Everybody love Obama bruh. (pause 0.09) And I'm- bruh, Obama is not like god damn like, hey, (pause 0.62) you should stop fucking with black people. (pause 1.62) [He the president.] He coulda just say that like, now. [Yeah?]
# Model Transcription:  They did they poco mama? Not the other world. Burr Obama was the president for eight years and he could say black people. Everybody little Obama burr and I broke Obama is not like I damn my A. Stop looking with black people. He could say that right now.
#
#
# Segment Start: 1320443.6
# Actual Transcript: I know y'all see me [/president/ out of this thing.] [But then they gonna say] he racist. Then they gonna say, why he just talking to black people? Like, da, da, da, da ,[da] [You] know they gonna say that, but now, I mean he gonna help everybody [man.] [Yeah.] <laugh> (pause 2.05) [He help, /??/.] [Some of y'all still doubt Obamacare.] Some of y'all niggas still got Obama Care, but (pause 1.76) I think that's really what it- they try to make it. (pause 0.91) Obamacare be like, okay. (pause 1.14) He was fucking with Obamacare now we got you.
# Model Transcription:  I know you're seeing me per... But did they go say he ranks? Did they go say why? He just talked with black people like, did it to the... They're not going to say that but now I mean he doesn't help everybody man. Yeah. Some of you asked, still that Obama care. Some of you still got Obama care. I think that's really what they try to make it. Obama care really well. Okay. If you were started with Obama care, then we got you.
#
#
# Segment Start: 1350443.6
# Actual Transcript: Right. But not /yet/. (pause 0.16) Anyway, (pause 0.36) It's tougher now. (pause 4.26) But then the same thing I see about the Obamacare now (pause 0.25) means and shit like that, now they switching it to the Donald Trump meanings and shit. Yeah. Like, oh, shit, you know. I'm the mother fucking president now so. (pause 0.99) You know. (pause 0.66) Get rid of the school debts, or some shit like that. (pause 2.12) [Bernie Sanders woulda been tight.] [I hope he just chill.] Right.
# Model Transcription:  Right.
#
#
# Segment Start: 1380443.6
# Actual Transcript: Right. (pause 0.35) He just would've been laid-back, (pause 0.12) old as hell. Old as hell, but he was gonna have some (pause 0.24) Yoda's type stuff. Yeah. (pause 2.13) <ts> (pause 0.07) I be trying to either get too deep into politics and stuff. I be listening to it- Mm-hm. but I don't really be- (pause 0.68) I don't never really have a response. Nah, me neither. I don't even know what the heck is going on over there. I think they just (pause 0.84) passing bills. And (pause 1.60) making paper (pause 0.52) you know, more than what it is, or whatever.
# Model Transcription:  I mean, he just would be layback all the time. I would be trying to even get too deep in politics. I mean, listening to it. But I don't really be. I don't really have a response.
#
#
# Segment Start: 1410443.6
# Actual Transcript: you know, more than what it is, or whatever. And then they talking about, (pause 0.81) somebody need to put Obama on the twenty-five dollar bill. (pause 0.42) Where is Obama on the twenty-five dollar [bill?] [That] would be kind of turnt [though.] [<laugh>] <laugh> (pause 0.68) Obama get the twenty-five dollar bill. Right. You know they gonna say something about that, but it ain't that big of a deal. <ts> [What- where Harriet Tubman sposta be?] The new twenty? [It's not. But the way that-] <laugh> Right. [<laugh>] [I think] that's /what is it/. Right. We get twenty-five,
# Model Transcription:  I'm more than what it is. And then it's time I'll somebody need to put Obama on the 25th of a bill. Where is Obama on the 25th of a bill? Every kind of time though. All right. You know they're gonna say something about that. But ain't that big of a bill. What is that? But the way you put it in the 20. All right. All right.
#
#
# Segment Start: 1440443.6
# Actual Transcript: We get twenty-five, (pause 1.78) I'm'a be cool. (pause 1.22) [Cause you know Benjamin Franklin.] [<laugh>] Nah, not Franklin. Um, (pause 0.17) Abraham Lincoln, what? He on the five dollar bill? I thought he was on the one dollar. I thought that was George Washington. Oh yeah, uh-huh. I think so. You know better than me. Let me see what the time is. Eleven thirteen. Let me see what that means on this, um, timer.
# Model Transcription:  I thought he was on the one da la. Oh yeah.
#
#
# Segment Start: 1470443.6
# Actual Transcript: Let me see what that means on this, um, timer. (pause 2.05) <sigh> That is some pretty good conversation though. Right. Alright. (pause 0.58) Gonna have the paperwork /unintelligible/. (pause 0.50) Oh, (pause 0.78) my phone just died. As always. Oh yeah, I can see wha- how much time is on the actual recorder. (pause 2.04) Ooh, don't drop it. Mm-mm.
# Model Transcription:  do what that means on this time. I'm not just pretty good conversation though. Right. All right. My paperwork club. Oh. I found it down. As a whole way. Oh yeah, I can see what I'm much time is on the actual court.
#
#
# Segment Start: 1500443.6
# Actual Transcript: Mm-mm. Twenty-five minutes? [<laugh>] [<laugh>] Oh you gotta /??/ that's unreal. (pause 0.74) /unintelligible/. (pause 11.50) What kind of workouts should we do? I don't be working out. (pause 0.73) I'm too little. (pause 0.13) I need to eat. Man, you lucky. (pause 1.02)
# Model Transcription:  So one, five minutes.
#
#
# Segment Start: 1530443.6
# Actual Transcript: (pause 1.02) You lucky, you don't gotta workout and you look like that. (pause 1.27) I don't gotta workout and I look like this. (pause 0.73) I be [still trying to workout-] <ts> (pause 0.21) [I wanna workout, but I] wanna gain some weight, then workout. I was waiting on that too. [When I gain weight-] [Is this fat club] right now I'm'a say /hey ms. fat/. Ah- <laugh> (pause 1.24) Yeah that's all I could say too. [<laugh>] [<laugh>] /Hey ms. fat/. [<laugh>] [<laugh>] Why your mama have to name me directly after [her?]
# Model Transcription:  I want to work out but I want to gain some weight.
#
#
# Segment Start: 1560443.6
# Actual Transcript: Why your mama have to name me directly after [her?] [I] have no idea, but I'm glad she did. /I follow [that], that's a slow move/. [<laugh>] You blush. She love you, [like-] [She] love me like a mother. [/unintelligible/.] [Hey.] (pause 1.11) [<laugh>] Both of y'all just p- [/unintelligible/.] [<laugh>] [<laugh>] [You] need a pat pat pat out of this motherfucker. <laugh> /unintelligible/. <laugh> Can't wait. /RD-NAME-3/ (pause 0.37) /RD-NAME-2/.
# Model Transcription:  I'm not an old lady, but I'm the one who does it. You love you, but...
#
#
# Segment Start: 1590443.6
# Actual Transcript: I'm been thinking about Peyton (pause 0.37) [lately.] [<gasp>] Peyton. (pause 0.27) Mm. That could go smooth for a boy or a girl. I know a little boy Peyton. I know two little boy Peytons Oh yeah? Mm-hm. Oh that's the /??/, man. (pause 1.90) Peyton /RD-NAME-1/ though, (pause 0.87) That sound like a motherfucker right there. Peyton Emmanuel. Ooh, Emmanuel. That's- (pause 0.08) that's pretty fire right there. Peyton Emmanuel /RD-NAME-1/.
# Model Transcription:  I'm thinking about painting. I'm going to put a little boy paint and I know two little boy paintings. Hey, I'm going to put a little boy paint. Hey, I'm going to put a little boy paint. Hey, I'm going to put a little boy paint. Hey, I'm going to put a little boy paint. Hey, I'm going to put a little boy paint.
#
#
# Segment Start: 1620443.6
# Actual Transcript: My son name is so ratchet. What are- /Well what/- (pause 0.40) /RD-NAME-2/ name go like, /RD-NAME-2/ [<laugh>] [/RD-NAME-4/] [Hey!] [/RD-NAME-5/] Then /RD-NAME-3/ <laugh> (pause 0.88) I kind of like that though. I told that man, /??/. (pause 0.17) I mean I told that man /RD-NAME-2/, if it be a little boy, (pause 0.19) <ts> (pause 0.12) Yeah. (pause 0.21) I let you name him. Ay. Man and it came around to be a little boy.
# Model Transcription:  Masala, name is so wretched. What is it? Name Goli.
#
#
# Segment Start: 1650443.6
# Actual Transcript: What you was gonna- If it wasn't a- If it was a girl, what you were gonna name- <ts> I don't know. I ain't even have no girl names in my head. Yeah, you just knew it was a boy. (pause 4.58) That sound crazy. I always hear like a lot of females say they rather have a boy than a girl (laughing). <laugh> Why is that though? Boys easy. Boys are easy huh? Boys are (pause 0.20) [chill.] [Boys-] [Why-] (pause 0.45) [why are females not easy?]
# Model Transcription:  What's he got if it wasn't a girl? I don't know I knew he had a girl named my name That's not a car is always here like a lot of female say they were to have a poor height in the car. Why is that? Boys easy Boys are easy boys are fun
#
#
# Segment Start: 1680443.6
# Actual Transcript: Because (pause 0.48) <ts> it's not a bad thing, [but] you gotta [Mm.] teach them more in a sense. You gotta- Mm-hm. Show them this and show them that. Boys, (pause 0.50) <ts> (pause 0.09) yeah, you gotta do the same, but it's like, (pause 2.56) <ts> (pause 0.19) I don't know. It's just- (pause 0.19) I don't think it's different raising them, I just feel like, (pause 0.81) I don't know. (pause 0.15) Like as far as cycles and bras and [this and body] odors. And- [Oh, snap.] Didn't even think about that [stuff.] [All that] stuff.
# Model Transcription:  Because it's not a bad thing, but you gotta teach them more in a sense. You gotta show them this and show them their boys. Yeah, you gotta do the same, but it's like, I don't know, I don't think it's different, right? You know, I just feel like, I don't know, like, it's fine with cycles and bras and these, and body odors and things about that. Oh, that's the...
#
#
# Segment Start: 1710443.6
# Actual Transcript: Mm, mm, mm, mm. Boys, (pause 0.35) none of that. Mm. (pause 1.20) So y'all- (pause 1.27) y'all endure like some pains that we won't even have (pause 0.58) never experienced. And then y'all bring like, life into the world. (pause 0.74) That's amazing man. Wh- what. (pause 2.88) It's the worst best (pause 0.25) craziest feeling in the world.
# Model Transcription:  Boy, let it.
#
#
# Segment Start: 1740443.6
# Actual Transcript: craziest feeling in the world. Ah, man. Mm-hm. (pause 2.81) /Like/ [that doggone /RD-NAME-2/.] [Women should at least be get-] Women should at least be getting paid around the same amounts as guys. If there's (pause 0.59) any type of, um, (pause 0.23) shit like that. <ts> (pause 0.06) [Mm-hm.] [I didn't think it] was like that. That's saying that, you know, women don't get paid as much as men and shit. Right. (pause 4.15)
# Model Transcription:  Why is he a swimming player?
#
#
# Segment Start: 1770443.6
# Actual Transcript: (pause 4.15) But you got more (pause 0.39) single mom households than single father [Damn.] [households.] Yeah. you- you kind of seen the number of the fathers turning up, but it's [still nowhere] near [Yeah.] what (pause 0.19) the mama's holding it down and shit [like that.] [Yeah.] Me and /RD-NAME-2/ gonna be like you and Miss /RD-NAME-1/, (pause 0.75) that's it.
# Model Transcription:  What you got more single mom households than single father? Yeah, you kind of seen a number of fathers turning out list. Yeah. What a mom was holding down. Me and W.I.U. and Miss. That's it.
#
#
# Segment Start: 1800443.6
# Actual Transcript: <laugh> You can have two rooms [Yeah.] <laugh> [too.] That shit gonna be crazy. Well we really used to live right here. Like (pause 0.33) <ts> Man I had that mother fucking basketball goal up. Okay. Doggone /???/. (pause 6.03)
# Model Transcription:  You've had two rooms. Yeah. Well, we really used to live right here, right? Man, I had that one. Mass above the old... Okay.
#
#
# Segment Start: 1830443.6
# Actual Transcript: (pause 6.03) When last time you played a video game? I don't really be playing video games. I just be playing games on my phone. Oh. What kind of games you play on your phone? Psh. [<laugh>] [Stupid] games. Real stupid games. Um, Cookie Jam [Two.] [Ooh.] I don't [know what that is.] [<ts>] (pause 0.11) [And then I be playing] the, um, Game Pigeon, games. [Wanna] play? [Hm.] Yeah let me- let me see it. Your phone dead. My phone all the way- it- And the charger right next to it.
# Model Transcription:  One last time I put a video game. I'm ready to play in games on my phone. I'm a game player in the phone. Stupid games, some rest of the games. Cookie Jam. And then I play in game-pitching games. Wanna play? You're a fan of Dave.
#
#
# Segment Start: 1860443.6
# Actual Transcript: My phone all the way- it- And the charger right next to it.
# Model Transcription:  in the Tars and Rainlands.

# %% [markdown]
# ## Word Error Rate (WER)
#
# Word Error Rate (WER) is a metric used to evaluate the performance of speech recognition systems. It measures the accuracy of a transcribed text compared to a reference (or ground truth) transcript by quantifying the number of errors in the predicted transcription.
#
# ### WER Calculation
#
# WER is calculated using the following formula:
#
# \[ \text{WER} = \frac{S + D + I}{N} \]
#
# where:
# - **S** is the number of substitutions (words that are incorrect in the prediction).
# - **D** is the number of deletions (words that are missing in the prediction).
# - **I** is the number of insertions (words that are extra in the prediction).
# - **N** is the total number of words in the reference transcript.
#
# ### Interpretation
#
# - **WER = 0%**: Perfect match between the predicted transcription and the reference transcript.
# - **WER > 0%**: Indicates some level of error; a higher WER signifies poorer performance of the transcription system.
#
# **Example**
#
# If the reference transcript is "Hello world" and the predicted transcript is "Hello there", the errors are:
# - **Substitutions**: "world" → "there" (1 substitution)
# - **Deletions**: None
# - **Insertions**: None
#
# Thus, WER = \( \frac{1}{2} = 0.5 \) or 50%, since there are 2 words in the reference transcript.
#
# WER provides a quantitative measure to compare different speech recognition systems or models, and to assess their performance in understanding and transcribing spoken language.
#
#
# 1. **Calculate WER:**
#    - `wer_score = wer(true_transcriptions, predicted_transcriptions)` computes the WER using the `jiwer` library.
#
# 2. **Print WER Score:**
#    - `print(f"Word Error Rate (WER): {wer_score}")` outputs the WER score to the console.

# %%
wer_score = wer(true_transcriptions, predicted_transcriptions)
print(f"Word Error Rate (WER): {wer_score}")
# Out:
# Word Error Rate (WER): 0.8459348870307775
